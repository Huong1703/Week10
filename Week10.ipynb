# %% [markdown]
# <a href="https://colab.research.google.com/github/Huong1703/Week10/blob/main/Week10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Visualizing Company Sale data

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
from collections import Counter

# set this so the graphs open internally
# %matplotlib inline

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://github.com/thieu1995/csv-files/blob/main/data/matplotlib/company_sales_data.csv).

# %%
users = pd.read_csv('https://raw.githubusercontent.com/thieu1995/csv-files/main/data/matplotlib/company_sales_data.csv', sep=',')
print(users)
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
#     moisturizer  total_units  total_profit
# 0          1500        21100        211000
# 1          1200        18330        183300
# 2          1340        22470        224700
# 3          1130        22270        222700
# 4          1740        20960        209600
# 5          1555        20140        201400
# 6          1120        29550        295500
# 7          1400        36140        361400
# 8          1780        23400        234000
# 9          1890        26670        266700
# 10         2100        41280        412800
# 11         1760        30020        300200

# %% [markdown]
# ### Exercise 1: Read Total profit of all months and show it using a line plot
#
# ![img](https://github.com/thieu1995/pandas/blob/main/11_matplotlib/company-sale/img/01.png?raw=1)

# %%
plt.figure(figsize=(10, 6))
plt.plot(users['month_number'], users['total_profit'], linestyle='-')
plt.title('Company profit per month')
plt.xlabel('Month number')
plt.ylabel('Total Profit')
plt.grid(False)
plt.xticks(range(1, max(users['month_number']) + 1, 1))
plt.yticks(range(0, max(users['total_profit']) + 1, 100000))
plt.show()

# %% [markdown]
# ### Exercise 2: Get total profit of all months and show line plot with the following Style properties
#
# ![img](https://github.com/thieu1995/pandas/blob/main/11_matplotlib/company-sale/img/02.png?raw=1)

# %%
plt.figure(figsize=(10, 6))
plt.plot(users['month_number'], users['total_profit'], color='b', linestyle='--', marker='o', markersize=8, linewidth=2)
plt.title('Company Sales data of last year')
plt.xlabel('Month Number')
plt.ylabel('Total Profit')
plt.grid(False)
plt.xticks(range(1, max(users['month_number']) + 1, 1))
plt.yticks(range(0, max(users['total_profit']) + 1, 100000))

plt.show()

# %% [markdown]
# ### Exercise 3: Read all product sales data and show it  using a multiline plot
#
# ![img](https://github.com/thieu1995/pandas/blob/main/11_matplotlib/company-sale/img/03.png?raw=1)

# %%
plt.figure(figsize=(12, 8))

for product in users.columns[1:-2]:
    plt.plot(users['month_number'], users[product], marker='o', label=product)

plt.title('Sales data')
plt.xlabel('Month Number')
plt.ylabel('Sales units in number')
plt.legend(loc='upper left', bbox_to_anchor=(1, 1))
plt.grid(False)
plt.xticks(range(1, max(users['month_number']) + 1, 1))
plt.show()

# %% [markdown]
# ### Exercise 4: Read toothpaste sales data of each month and show it using a scatter plot
# ![img](https://github.com/thieu1995/pandas/blob/main/11_matplotlib/company-sale/img/04.png?raw=1)

# %%
plt.figure(figsize=(10, 6))
plt.scatter(users['month_number'], users['toothpaste'], color='blue', marker='o')
plt.title('Tooth paste Sales data')
plt.xlabel('Month Number')
plt.ylabel('Number of units Sold')
plt.grid(True, linestyle='--', alpha=0.7)
plt.xticks(range(1, max(users['month_number']) + 1, 1))
plt.show()

# %% [markdown]
# ### Exercise 5: Read face cream and facewash product sales data and show it using the bar chart
#
# ![img](https://github.com/thieu1995/pandas/blob/main/11_matplotlib/company-sale/img/05.png?raw=1)

# %%
plt.figure(figsize=(10, 6))
bar_width = 0.35

plt.bar(users['month_number'] - bar_width/2, users['facecream'], bar_width, label='Face Cream', color='blue')
plt.bar(users['month_number'] + bar_width/2, users['facewash'], bar_width, label='Face Wash', color='orange')

plt.title('Facewash and facecream sales data')
plt.xlabel('Month Number')
plt.ylabel('Sales units in numbers')
plt.legend()
plt.grid(True, linestyle='--', alpha=0.7)
plt.xticks(range(1, max(users['month_number']) + 1, 1))
plt.show()

# %% [markdown]
# ### Exercise 6: Read sales data of bathing soap of all months and show it using a bar chart. Save this plot to your hard disk
#
# ![img](https://github.com/thieu1995/pandas/blob/main/11_matplotlib/company-sale/img/06.png?raw=1)

# %%
plt.figure(figsize=(10, 6))
plt.bar(users['month_number'], users['bathingsoap'])
plt.title('bathingsoap sales data')
plt.xlabel('Month Number')
plt.ylabel('Sales units in number')
plt.savefig('bathing_soap_sales_plot.png')
plt.grid(True, linestyle='--', alpha=0.7)
plt.xticks(range(1, max(users['month_number']) + 1, 1))
plt.show()

# %% [markdown]
# ### Exercise 7: Read the total profit of each month and show it using the histogram to see the most common profit ranges
#
# ![img](https://github.com/thieu1995/pandas/blob/main/11_matplotlib/company-sale/img/07.png?raw=1)

# %%
plt.figure(figsize=(10, 6))
plt.hist(users['total_profit'], bins=10, color='orange', edgecolor='black')  # Adjust the number of bins as needed
plt.title('Distribution of Total Profit Over Months')
plt.xlabel('Total Profit')
plt.ylabel('Frequency')

plt.show()

# %% [markdown]
# ### Exercise 8: Calculate total sale data for last year for each product and show it using a Pie chart
#
# ![img](https://github.com/thieu1995/pandas/blob/main/11_matplotlib/company-sale/img/08.png?raw=1)

# %%
total_sales = users.iloc[:, 1:-2].sum()

plt.figure(figsize=(10, 6))
plt.pie(total_sales, labels=total_sales.index, autopct='%1.1f%%', startangle=140, colors=['#ff9999', '#66b3ff', '#99ff99', '#ffcc99', '#c2c2f0', '#ffb3e6'])
plt.title('Sales data')

plt.show()

# %% [markdown]
# ### Exercise 9: Read Bathing soap facewash of all months and display it using the Subplot
#
# ![img](https://github.com/thieu1995/pandas/blob/main/11_matplotlib/company-sale/img/09.png?raw=1)

# %%
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.plot(users['month_number'], users['bathingsoap'], marker='o', color='black')
plt.title('Sales data of a Bathingsoap')
plt.xlabel('Month Number')
plt.ylabel('Sales Units in number')


plt.subplot(1, 2, 2)
plt.plot(users['month_number'], users['facewash'], marker='o', color='r')
plt.title('Sales data of a facewash')
plt.xlabel('Month Number')
plt.ylabel('Sales Units in number')


plt.tight_layout()
plt.show()

# %% [markdown]
# ### Exercise 10: Read all product sales data and show it using the stack plot
#
# ![img](https://github.com/thieu1995/pandas/blob/main/11_matplotlib/company-sale/img/10.png?raw=1)

# %% [markdown]
# ### Exercise 6: Read sales data of bathing soap of all months and show it using a bar chart. Save this plot to your hard disk
#
# ![img](https://github.com/thieu1995/pandas/blob/main/11_matplotlib/company-sale/img/06.png?raw=1)

# %% [markdown]
# ### Exercise 7: Read the total profit of each month and show it using the histogram to see the most common profit ranges
#
# ![img](https://github.com/thieu1995/pandas/blob/main/11_matplotlib/company-sale/img/07.png?raw=1)

# %% [markdown]
# ### Exercise 8: Calculate total sale data for last year for each product and show it using a Pie chart
#
# ![img](https://github.com/thieu1995/pandas/blob/main/11_matplotlib/company-sale/img/08.png?raw=1)

# %% [markdown]
# ### Exercise 9: Read Bathing soap facewash of all months and display it using the Subplot
#
# ![img](https://github.com/thieu1995/pandas/blob/main/11_matplotlib/company-sale/img/09.png?raw=1)

# %% [markdown]
# ### Exercise 10: Read all product sales data and show it using the stack plot
#
# ![img](https://github.com/thieu1995/pandas/blob/main/11_matplotlib/company-sale/img/10.png?raw=1)

# %%
plt.figure(figsize=(10, 6))
plt.stackplot(users['month_number'], users.iloc[:, 1:-2].T, labels=users.columns[1:-2], colors=plt.cm.tab10.colors)
plt.title('All Product Sales Data using stack plot')
plt.xlabel('Month')
plt.ylabel('Sales units in number')
plt.legend(loc='upper left')
plt.xticks(users['month_number'])
plt.tight_layout()
plt.show()
